# %%
import pandas as pd

# %%
df = pd.read_csv('loan_ds.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9311 entries, 0 to 9310
# Data columns (total 33 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   End of Period                     9311 non-null   object
#  1   Loan Number                       9311 non-null   object
#  2   Region                            9311 non-null   object
#  3   Country / Economy Code            9308 non-null   object
#  4   Country / Economy                 9311 non-null   object
#  5   Borrower                          9254 non-null   object
#  6   Guarantor Country / Economy Code  9028 non-null   object
#  7   Guarantor                         9031 non-null   object
#  8   Loan Type                         9311 non-null   object
#  9   Loan Status                       9311 non-null   object
#  10  Interest Rate                     9211 non-null   float64
# ...

# %%
# Atributos com dados faltantes
df[df.columns[df.count() < 9311]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9311 entries, 0 to 9310
# Data columns (total 13 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country / Economy Code            9308 non-null   object
#  1   Borrower                          9254 non-null   object
#  2   Guarantor Country / Economy Code  9028 non-null   object
#  3   Guarantor                         9031 non-null   object
#  4   Interest Rate                     9211 non-null   float64
#  5   Currency of Commitment            0 non-null      float64
#  6   Project Name                      9285 non-null   object
#  7   First Repayment Date              9260 non-null   object
#  8   Last Repayment Date               9261 non-null   object
#  9   Agreement Signing Date            9154 non-null   object
#  10  Effective Date (Most Recent)      9218 non-null   object
# ...

# %% [markdown]
# - _Country / Economy_ e _Country / Economy code_ parecem se a mesma feature, mas a última tem 3 registros faltantes. Talvez de para preencher manualmente
# - Borrower parece ser uma features importante, mas tem uma quantidade grande de dados faltantes. Investigar melhor para ver como melhorar
# - _Guarantor_ e _Guarantor Country / Economy Code_ possuem uma quantodade razoavel de dados faltantes
# - Eliminar a feature _Currency of Commitent_ por todos os valores serem nulos
# - Observar se _Last Disbursement Date_ é uma feature de interesse, pois há muitos dados faltantes
# - _Project Name_ também tem uma quantidade razoável de registros faltantes, mas será descartada provavelmente, já que temos _Project ID_

# %%
df.describe()
# Out:
#        Interest Rate  Currency of Commitment  Original Principal Amount (US$)  \
# count    9211.000000                     0.0                     9.311000e+03
# mean        3.928130                     NaN                     9.976537e+07
# std         3.462785                     NaN                     1.721374e+08
# min         0.000000                     NaN                     0.000000e+00
# 25%         0.000000                     NaN                     1.400000e+07
# 50%         4.750000                     NaN                     4.000000e+07
# 75%         7.150000                     NaN                     1.062500e+08
# max        11.600000                     NaN                     3.750000e+09
#
#        Cancelled Amount (US$)  Undisbursed Amount (US$)  \
# count            9.311000e+03              9.311000e+03
# mean             1.189091e+07              1.000730e+07
# std              5.010706e+07              5.399782e+07
# ...

# %%
df.describe(include=['object', 'bool'])
# Out:
#        End of Period Loan Number                       Region  \
# count           9311        9311                         9311
# unique             1        9311                            7
# top       05/31/2025   IBRDB1031  LATIN AMERICA AND CARIBBEAN
# freq            9311           1                         2917
#
#        Country / Economy Code Country / Economy             Borrower  \
# count                    9308              9311                 9254
# unique                    146               147                  957
# top                        ID         Indonesia  MINISTRY OF FINANCE
# freq                      652               652                 1259
#
#        Guarantor Country / Economy Code  Guarantor Loan Type   Loan Status  \
# count                              9028       9031      9311          9311
# unique                              125        126        11            11
# top                                  ID  Indonesia       FSL  Fully Repaid
# ...

# %%
df.
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df.columns['interest_rate']
#
# File ~/academics/iml/codes/.venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:5416, in Index.__getitem__(self, key)
#    5407         if len(key) == 0 and len(key) != len(self):
#    5408             warnings.warn(
#    5409                 "Using a boolean indexer with length 0 on an Index with "
#    5410                 "length greater than 0 is deprecated and will raise in a "
#    (...)
#    5413                 stacklevel=find_stack_level(),
#    5414             )
# -> 5416 result = getitem(key)
#    5417 # Because we ruled out integer above, we always get an arraylike here
#    5418 if result.ndim > 1:
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
